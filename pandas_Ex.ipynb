# %%
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("chipotle.csv",sep = "	")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
titanic = pd.read_csv("titanic-passengers.csv",sep = ";")
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Name","Age"]]
# Out:
#                                                   Name   Age
# 0                           Collander, Mr. Erik Gustaf  28.0
# 1                              Moen, Mr. Sigurd Hansen  25.0
# 2                               Jensen, Mr. Hans Peder  20.0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  29.0
# 4                               Davidson, Mr. Thornton  31.0
# ..                                                 ...   ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 887                              Sirayanian, Mr. Orsen  22.0
# 888                                Cacic, Miss. Marija  30.0
# 889                   Petroff, Mr. Pastcho ("Pentcho")   NaN
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  19.0
#
# [891 rows x 2 columns]

# %%
titanic[(titanic["Age"]>30) & (titanic["Survived"] == "Yes")]
# Out:
#      PassengerId Survived  Pclass  \
# 9            433      Yes       2
# 12           755      Yes       2
# 19           225      Yes       1
# 22           544      Yes       2
# 24           273      Yes       2
# ..           ...      ...     ...
# 843           16      Yes       2
# 857          514      Yes       1
# 863          858      Yes       1
# 865          196      Yes       1
# 882          775      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9    Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 12                    Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 19                        Hoyt, Mr. Frederick Maxfield    male  38.0      1
# 22                                   Beane, Mr. Edward    male  32.0      1
# 24           Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x = "Collander, Mr. Erik Gustaf"
x.split(".")[0].split(",")[1][1:]
# Out:
# 'Mr'

# %%
titanic.to_excel("titanic2.xlsx")

# %%
titanic["title"] = titanic["Name"].apply(lambda x:x.split(".")[0].split(",")[1][1:])
titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
s = "$2.30"
float(s[1:])
# Out:
# 2.3

# %%
df["item_price"] = df["item_price"].apply(lambda x:float(x[1:]))
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...
